# %% [markdown]
# ![](https://miro.medium.com/max/1400/1*f2-zeAOSNB4RGlqH9emTlQ.jpeg)

# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, TimeoutException, ElementNotInteractableException, ElementClickInterceptedException
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %%
#webdriver
driver=webdriver.Chrome(r"D:\chromedriver\chromedriver.exe")
time.sleep(3)

# %%
#cartrade

# Opening the homepage of cartrade

url = "https://www.cartrade.com/"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="ucity"]').click()
driver.find_element_by_xpath('//*[@id="ucity"]/optgroup[1]/option[1]').click()
driver.find_element_by_xpath('//*[@id="rvwtop"]/div/div[1]/div[2]/div[2]/input').click()
time.sleep(2)
bodytype = driver.find_element_by_xpath('//*[@id="selectlistarrow6"]')
Hatchback = driver.find_element_by_xpath('//*[@id="body_Hatchback"]')
Sedan = driver.find_element_by_xpath('//*[@id="body_Sedan"]')
SUV = driver.find_element_by_xpath('//*[@id="body_SUV"]')
Van_Minivan = driver.find_element_by_xpath('//*[@id="body_Van_Minivan"]')
action= ActionChains(driver)
action.move_to_element(bodytype).move_to_element(Hatchback).click().move_to_element(Sedan).click().move_to_element(SUV).click().move_to_element(Van_Minivan).click().perform()

# %%
links1=[]
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
try:
    for l in driver.find_elements_by_xpath('//h2[@class="h2heading truncate"]/a'):
        links1.append(l.get_attribute('href'))
        time.sleep(1)
except NoSuchElementException:
        links1.append("-")
        time.sleep(1)
for page in range(0,10):
        nxt_button=driver.find_elements_by_xpath('//div[@class="pagination"]/ul/li[@class="next"]/a')#scraping the list of buttons from the page
        time.sleep(2)
        try:
            driver.get(nxt_button[1].get_attribute('href'))#getting the link from the list for next page
            time.sleep(2)
        except:
            driver.get(nxt_button[0].get_attribute('href'))
            time.sleep(2)
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        time.sleep(2)
        try:
            for l in driver.find_elements_by_xpath('//h2[@class="h2heading truncate"]/a'):
                links1.append(l.get_attribute('href'))
                time.sleep(1)
        except NoSuchElementException:
                links1.append("-")
                time.sleep(1)

# %%
len(links1)
# Out:
# 271

# %%
# Opening the homepage of cartrade

url = "https://www.cartrade.com/"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="ucity"]').click()
driver.find_element_by_xpath('//*[@id="ucity"]/optgroup[1]/option[2]').click()
driver.find_element_by_xpath('//*[@id="rvwtop"]/div/div[1]/div[2]/div[2]/input').click()
time.sleep(2)
bodytype = driver.find_element_by_xpath('//*[@id="selectlistarrow6"]')
Hatchback = driver.find_element_by_xpath('//*[@id="body_Hatchback"]')
Sedan = driver.find_element_by_xpath('//*[@id="body_Sedan"]')
SUV = driver.find_element_by_xpath('//*[@id="body_SUV"]')
Van_Minivan = driver.find_element_by_xpath('//*[@id="body_Van_Minivan"]')
action= ActionChains(driver)
action.move_to_element(bodytype).move_to_element(Hatchback).click().move_to_element(Sedan).click().move_to_element(SUV).click().move_to_element(Van_Minivan).click().perform()

# %%
links2=[]
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
try:
    for l in driver.find_elements_by_xpath('//h2[@class="h2heading truncate"]/a'):
        links2.append(l.get_attribute('href'))
        time.sleep(1)
except NoSuchElementException:
        links2.append("-")
        time.sleep(1)
        
for page in range(0,10):
        nxt_button=driver.find_elements_by_xpath('//div[@class="pagination"]/ul/li[@class="next"]/a')#scraping the list of buttons from the page
        time.sleep(2)
        try:
            driver.get(nxt_button[1].get_attribute('href'))#getting the link from the list for next page
            time.sleep(2)
        except:
            driver.get(nxt_button[0].get_attribute('href'))
            time.sleep(2)
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        time.sleep(2)
        try:
            for l in driver.find_elements_by_xpath('//h2[@class="h2heading truncate"]/a'):
                links2.append(l.get_attribute('href'))
                time.sleep(1)
        except NoSuchElementException:
                links2.append("-")
                time.sleep(1)

# %%
len(links2)
# Out:
# 271

# %%
# Opening the homepage of cartrade

url = "https://www.cartrade.com/"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="ucity"]').click()
driver.find_element_by_xpath('//*[@id="ucity"]/optgroup[1]/option[3]').click()
driver.find_element_by_xpath('//*[@id="rvwtop"]/div/div[1]/div[2]/div[2]/input').click()
time.sleep(2)
bodytype = driver.find_element_by_xpath('//*[@id="selectlistarrow6"]')
Hatchback = driver.find_element_by_xpath('//*[@id="body_Hatchback"]')
Sedan = driver.find_element_by_xpath('//*[@id="body_Sedan"]')
SUV = driver.find_element_by_xpath('//*[@id="body_SUV"]')
Van_Minivan = driver.find_element_by_xpath('//*[@id="body_Van_Minivan"]')
action= ActionChains(driver)
action.move_to_element(bodytype).move_to_element(Hatchback).click().move_to_element(Sedan).click().move_to_element(SUV).click().move_to_element(Van_Minivan).click().perform()

# %%
links3=[]
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
try:
    for l in driver.find_elements_by_xpath('//h2[@class="h2heading truncate"]/a'):
        links3.append(l.get_attribute('href'))
        time.sleep(1)
except NoSuchElementException:
        links3.append("-")
        time.sleep(1)
        
for page in range(0,10):
        nxt_button=driver.find_elements_by_xpath('//div[@class="pagination"]/ul/li[@class="next"]/a')#scraping the list of buttons from the page
        time.sleep(2)
        try:
            driver.get(nxt_button[1].get_attribute('href'))#getting the link from the list for next page
            time.sleep(2)
        except:
            driver.get(nxt_button[0].get_attribute('href'))
            time.sleep(2)
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        time.sleep(2)
        try:
            for l in driver.find_elements_by_xpath('//h2[@class="h2heading truncate"]/a'):
                links3.append(l.get_attribute('href'))
                time.sleep(1)
        except NoSuchElementException:
                links3.append("-")
                time.sleep(1)

# %%
len(links3)
# Out:
# 264

# %%
links=links1+links2+links3
len(links)
# Out:
# 806

# %%
Brand=[]
Model=[]
Variant=[]
Man_year=[]
Driven_km=[]
Fuel=[]
Num_of_owners=[]
Location=[]
Price=[]

# %%
for url in links:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[1]/div/ul/li[4]/a/span')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[1]/div/ul/li[5]/a/span')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[1]/div/ul/li[6]/span')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[8]/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[8]/td[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[8]/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[3]/td[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[8]/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[8]/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[5]/td[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[8]/div[1]/div[2]/div/div[4]/table/tbody/tr[1]/td[2]')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[8]/div[1]/div[2]/div/div[1]/div[1]/span[2]')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# dictionary of lists 
dict1 = {'Brand': Brand, 'Model': Model, 'Variant': Variant,'Man_year':Man_year,'Driven_km':Driven_km,'Fuel':Fuel,
         'Num_of_owners':Num_of_owners,'Location':Location,'Price':Price} 
     
df = pd.DataFrame(dict1)
  
# saving the dataframe
df.to_csv('cartrade.csv')

# %%
#webdriver
driver=webdriver.Chrome(r"D:\chromedriver\chromedriver.exe")
time.sleep(3)

# %%
#olx


# Opening the homepage of olx

url = "https://www.olx.in/cars_c84"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//ul[@class="_3eZBP _1TJht rui-1Culj _2XSBC"]/li/a').click()
time.sleep(2)
driver.find_element_by_xpath('//ul[@class="_3eZBP _1TJht rui-1Culj _2XSBC"]/li/ul/li[1]/a').click()
time.sleep(2)
driver.find_element_by_xpath('//ul[@class="_3eZBP _1TJht rui-1Culj _2XSBC"]/li/ul/li/ul/li[1]/a').click()

# %%
links1=[]
for page in range(0,15):
    try:
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        driver.find_element_by_xpath('//li[@class="_20FqS"]/div[@class="JbJAl"]').click()
        time.sleep(2)
    except NoSuchElementException:
        pass

# %%
try:
    for l in driver.find_elements_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a'):
        links1.append(l.get_attribute('href'))
        time.sleep(1)
except NoSuchElementException:
        links1.append("-")
        time.sleep(2)

# %%
len(links1)
# Out:
# 358

# %%
Brand=[]
Model=[]
Variant=[]
Man_year=[]
Driven_km=[]
Fuel=[]
Num_of_owners=[]
Location=[]
Price=[]

# %%
for url in links1:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[2]')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[2]')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[5]/div[1]/div/section/span[1]')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# Opening the homepage of cartrade

url = "https://www.olx.in/cars_c84"
driver.get(url)

time.sleep(2)
#driver.find_element_by_xpath('//*[@id="ucity"]').click()
driver.find_element_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[1]/div/div[2]/div[3]/ul/li/a').click()
time.sleep(2)
driver.find_element_by_xpath('//a[@data-aut-id="location_Delhi"]').click()

# %%
for page in range(0,10):
    try:
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        driver.find_element_by_xpath('//li[@class="_20FqS"]/div[@class="JbJAl"]').click()
        time.sleep(1)
    except NoSuchElementException:
        pass

# %%
links2=[]
try:
    for l in driver.find_elements_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a'):
        links2.append(l.get_attribute('href'))
        time.sleep(1)
except NoSuchElementException:
        links2.append("-")
        time.sleep(1)

# %%
len(links2)
# Out:
# 360

# %%
for url in links2:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[2]')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[2]')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[5]/div[1]/div/section/span[1]')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# Opening the homepage of cartrade
#Tamil Nadu
url = "https://www.olx.in/cars_c84"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[1]/div/div[2]/div[3]/ul/li/a').click()
time.sleep(2)
driver.find_element_by_xpath('//a[@data-aut-id="location_Tamil Nadu"]').click()
#driver.find_element_by_xpath('//a[@data-aut-id="location_Tamil Nadu"]/ul/li[1]/a').click()

# %%
for page in range(0,10):
    try:
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        driver.find_element_by_xpath('//li[@class="_20FqS"]/div[@class="JbJAl"]').click()
        time.sleep(1)
    except NoSuchElementException:
        pass

# %%
links3=[]

try:
    for l in driver.find_elements_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a'):
        links3.append(l.get_attribute('href'))
        time.sleep(1)
except NoSuchElementException:
        links3.append("-")
        time.sleep(1)

# %%
len(links3)
# Out:
# 479

# %%
for url in links3:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[2]')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[2]')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel
        try:
            f = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[5]/div[1]/div/section/span[1]')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# Opening the homepage of cartrade
#Kochi
url = "https://www.olx.in/cars_c84"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[1]/div/div[2]/div[3]/ul/li/a').click()
time.sleep(2)
driver.find_element_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[1]/div/div[2]/div[3]/ul/li/ul/li[3]').click()
time.sleep(2)
driver.find_element_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[1]/div/div[2]/div[3]/ul/li/ul/li/ul/li[1]').click()

# %%
for page in range(0,10):
    try:
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        driver.find_element_by_xpath('//li[@class="_20FqS"]/div[@class="JbJAl"]').click()
        time.sleep(1)
    except NoSuchElementException:
        pass

# %%
links4=[]
try:
    for l in driver.find_elements_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a'):
        links4.append(l.get_attribute('href'))
        time.sleep(1)
except NoSuchElementException:
        links4.append("-")
        time.sleep(1)

# %%
len(links4)
# Out:
# 646

# %%
for url in links4:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[2]')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[2]')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[5]/div[1]/div/section/span[1]')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# Opening the homepage of cartrade
#Lucknow
url = "https://www.olx.in/cars_c84"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[1]/div/div[2]/div[3]/ul/li/a').click()
time.sleep(2)
driver.find_element_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[1]/div/div[2]/div[3]/ul/li/ul/li[4]').click()
time.sleep(2)
driver.find_element_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[1]/div/div[2]/div[3]/ul/li/ul/li/ul/li[1]').click()

# %%
for page in range(0,3):
    try:
        driver.find_element_by_xpath('//li[@class="_20FqS"]/div[@class="JbJAl"]').click()
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        time.sleep(1)
    except NoSuchElementException:
        pass

# %%
links5=[]
try:
    for l in driver.find_elements_by_xpath('//*[@id="container"]/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a'):
        links5.append(l.get_attribute('href'))
        time.sleep(1)
except NoSuchElementException:
        links5.append("-")
        time.sleep(1)

# %%
len(links5)
# Out:
# 160

# %%
for url in links5:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[1]/div/span[2]')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[2]/div/span[2]')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[3]/div/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[4]/div/span[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[7]/div/span[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[5]/div/span[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[4]/section[1]/div/div/div[1]/div/div[8]/div/span[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[5]/div[1]/div/section/div/div[1]/div/span')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('//*[@id="container"]/main/div/div/div/div[5]/div[1]/div/section/span[1]')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# dictionary of lists 
dict2 = {'Brand': Brand, 'Model': Model, 'Variant': Variant,'Man_year':Man_year,'Driven_km':Driven_km,'Fuel':Fuel,
         'Num_of_owners':Num_of_owners,'Location':Location,'Price':Price} 
     
df1 = pd.DataFrame(dict2)
  
# saving the dataframe
df1.to_csv('Olx.csv')

# %%
#webdriver
driver=webdriver.Chrome(r"D:\chromedriver\chromedriver.exe")
time.sleep(3)

# %%
#carwale


# Opening the homepage of cartrade
#Delhi
url = "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&pn=1"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="closeLocIcon"]').click()
time.sleep(2)

driver.find_element_by_xpath('//*[@id="drpCity"]').click()
driver.find_element_by_xpath('//*[@id="drpCity"]/option[3]').click()

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
links1=[]
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
for i in range(1,7):
    try:
        for l in driver.find_elements_by_xpath(f'//*[@id="listing{i}"]/li/div/div/div/div[1]/a'):
            links1.append(l.get_attribute('href'))
            time.sleep(1)
    except NoSuchElementException:
            pass
            time.sleep(1)

# %%
len(links1)
# Out:
# 127

# %%
Brand=[]
Model=[]
Variant=[]
Man_year=[]
Driven_km=[]
Fuel=[]
Num_of_owners=[]
Location=[]
Price=[]

# %%
for url in links1:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[6]/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[2]/div[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[3]/div[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel  
        try:
            f = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[4]/div[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[9]/div[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[1]/div[2]/ul/li[5]/span[2]')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[2]/div/div[1]/div[1]/div/div[1]/p')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# Opening the homepage of cartrade
#mumbai
url = "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&pn=1"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="closeLocIcon"]').click()
time.sleep(2)

driver.find_element_by_xpath('//*[@id="drpCity"]').click()
driver.find_element_by_xpath('//*[@id="drpCity"]/option[4]').click()

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
links2=[]

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
for i in range(1,7):
    try:
        for l in driver.find_elements_by_xpath(f'//*[@id="listing{i}"]/li/div/div/div/div[1]/a'):
            links2.append(l.get_attribute('href'))
            time.sleep(1)
    except NoSuchElementException:
            pass
            time.sleep(1)

# %%
len(links2)
# Out:
# 128

# %%
for url in links2:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[6]/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[2]/div[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[3]/div[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[4]/div[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[9]/div[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[1]/div[2]/ul/li[5]/span[2]')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[2]/div/div[1]/div[1]/div/div[1]/p')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# Opening the homepage of cartrade
#Thane
url = "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&pn=1"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="closeLocIcon"]').click()
time.sleep(2)

driver.find_element_by_xpath('//*[@id="drpCity"]').click()
driver.find_element_by_xpath('//*[@id="drpCity"]/option[5]').click()

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
links3=[]

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(3)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(3)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(3)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(3)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(3)
for i in range(1,10):
    try:
        for l in driver.find_elements_by_xpath(f'//*[@id="listing{i}"]/li/div/div/div/div[1]/a'):
            links3.append(l.get_attribute('href'))
            time.sleep(1)
    except NoSuchElementException:
            pass
            time.sleep(1)

# %%
len(links3)
# Out:
# 224

# %%
for url in links3:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[6]/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[2]/div[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[3]/div[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[4]/div[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[9]/div[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[1]/div[2]/ul/li[5]/span[2]')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[2]/div/div[1]/div[1]/div/div[1]/p')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# Opening the homepage of cartrade
#banglore
url = "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&pn=1"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="closeLocIcon"]').click()
time.sleep(2)

driver.find_element_by_xpath('//*[@id="drpCity"]').click()
driver.find_element_by_xpath('//*[@id="drpCity"]/option[7]').click()

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
links4=[]

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
for i in range(1,7):
    try:
        for l in driver.find_elements_by_xpath(f'//*[@id="listing{i}"]/li/div/div/div/div[1]/a'):
            links4.append(l.get_attribute('href'))
            time.sleep(1)
    except NoSuchElementException:
            pass
            time.sleep(1)

# %%
len(links4)
# Out:
# 127

# %%
for url in links4:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[6]/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[2]/div[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[3]/div[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[4]/div[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[9]/div[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[1]/div[2]/ul/li[5]/span[2]')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[2]/div/div[1]/div[1]/div/div[1]/p')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# Opening the homepage of cartrade
#Chennai
url = "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&pn=1"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="closeLocIcon"]').click()
time.sleep(2)

driver.find_element_by_xpath('//*[@id="drpCity"]').click()
driver.find_element_by_xpath('//*[@id="drpCity"]/option[8]').click()

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
links5=[]

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
for i in range(1,7):
    try:
        for l in driver.find_elements_by_xpath(f'//*[@id="listing{i}"]/li/div/div/div/div[1]/a'):
            links5.append(l.get_attribute('href'))
            time.sleep(1)
    except NoSuchElementException:
            pass
            time.sleep(1)

# %%
len(links5)
# Out:
# 128

# %%
for url in links5:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[6]/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[2]/div[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[3]/div[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[4]/div[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[9]/div[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[1]/div[2]/ul/li[5]/span[2]')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[2]/div/div[1]/div[1]/div/div[1]/p')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# Opening the homepage of cartrade
#Kolkata 
url = "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&pn=1"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="closeLocIcon"]').click()
time.sleep(2)

driver.find_element_by_xpath('//*[@id="drpCity"]').click()
driver.find_element_by_xpath('//*[@id="drpCity"]/option[9]').click()

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
links6=[]

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
for i in range(1,7):
    try:
        for l in driver.find_elements_by_xpath(f'//*[@id="listing{i}"]/li/div/div/div/div[1]/a'):
            links6.append(l.get_attribute('href'))
            time.sleep(1)
    except NoSuchElementException:
            pass
            time.sleep(1)

# %%
len(links6)
# Out:
# 125

# %%
for url in links6:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[6]/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[2]/div[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[3]/div[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[4]/div[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[9]/div[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[1]/div[2]/ul/li[5]/span[2]')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[2]/div/div[1]/div[1]/div/div[1]/p')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# Opening the homepage of cartrade
#Ahmedabad
url = "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&pn=1"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="closeLocIcon"]').click()
time.sleep(2)

driver.find_element_by_xpath('//*[@id="drpCity"]').click()
driver.find_element_by_xpath('//*[@id="drpCity"]/option[10]').click()

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
links7=[]

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
for i in range(1,7):
    try:
        for l in driver.find_elements_by_xpath(f'//*[@id="listing{i}"]/li/div/div/div/div[1]/a'):
            links7.append(l.get_attribute('href'))
            time.sleep(1)
    except NoSuchElementException:
            pass
            time.sleep(1)

# %%
len(links7)
# Out:
# 127

# %%
for url in links7:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[6]/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[2]/div[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[3]/div[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[4]/div[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[9]/div[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[1]/div[2]/ul/li[5]/span[2]')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[2]/div/div[1]/div[1]/div/div[1]/p')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# Opening the homepage of cartrade
#Pune
url = "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&pn=1"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="closeLocIcon"]').click()
time.sleep(2)

driver.find_element_by_xpath('//*[@id="drpCity"]').click()
driver.find_element_by_xpath('//*[@id="drpCity"]/option[11]').click()

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
links8=[]

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
for i in range(1,11):
    try:
        for l in driver.find_elements_by_xpath(f'//*[@id="listing{i}"]/li/div/div/div/div[1]/a'):
            links8.append(l.get_attribute('href'))
            time.sleep(1)
    except NoSuchElementException:
            pass
            time.sleep(1)

# %%
len(links8)
# Out:
# 224

# %%
for url in links8:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[6]/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[2]/div[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[3]/div[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[4]/div[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[9]/div[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[1]/div[2]/ul/li[5]/span[2]')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[2]/div/div[1]/div[1]/div/div[1]/p')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# Opening the homepage of cartrade
#Hyderabad
url = "https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&pn=1"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="closeLocIcon"]').click()
time.sleep(2)

driver.find_element_by_xpath('//*[@id="drpCity"]').click()
driver.find_element_by_xpath('//*[@id="drpCity"]/option[12]').click()

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
links9=[]

driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(1)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
for i in range(1,8):
    try:
        for l in driver.find_elements_by_xpath(f'//*[@id="listing{i}"]/li/div/div/div/div[1]/a'):
            links9.append(l.get_attribute('href'))
            time.sleep(1)
    except NoSuchElementException:
            pass
            time.sleep(1)

# %%
len(links9)
# Out:
# 151

# %%
for url in links9:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[4]/a/span')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[5]/a/span')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[1]/div[1]/div[1]/ul/li[6]/span[2]')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[2]/div[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[3]/div[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[4]/div[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="overview"]/div/ul/li[9]/div[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[1]/div[2]/ul/li[5]/span[2]')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('/html/body/div[14]/section[2]/div[2]/div[2]/div/div[1]/div[1]/div/div[1]/p')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# dictionary of lists 
dict3 = {'Brand': Brand, 'Model': Model, 'Variant': Variant,'Man_year':Man_year,'Driven_km':Driven_km,'Fuel':Fuel,
         'Num_of_owners':Num_of_owners,'Location':Location,'Price':Price} 
     
df3 = pd.DataFrame(dict3)
  
# saving the dataframe
df3.to_csv('carwale.csv')

# %%
#webdriver
driver=webdriver.Chrome(r"D:\chromedriver\chromedriver.exe")
time.sleep(3)

# %%
#cartrade


# Opening the homepage of cartrade

url = "https://www.cartrade.com/"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="ucity"]').click()
driver.find_element_by_xpath('//*[@id="ucity"]/optgroup[1]/option[4]').click()
driver.find_element_by_xpath('//*[@id="rvwtop"]/div/div[1]/div[2]/div[2]/input').click()
time.sleep(2)
bodytype = driver.find_element_by_xpath('//*[@id="selectlistarrow6"]')
Hatchback = driver.find_element_by_xpath('//*[@id="body_Hatchback"]')
Sedan = driver.find_element_by_xpath('//*[@id="body_Sedan"]')
SUV = driver.find_element_by_xpath('//*[@id="body_SUV"]')
Van_Minivan = driver.find_element_by_xpath('//*[@id="body_Van_Minivan"]')
action= ActionChains(driver)
action.move_to_element(bodytype).move_to_element(Hatchback).click().move_to_element(Sedan).click().move_to_element(SUV).click().move_to_element(Van_Minivan).click().perform()

# %%
links1=[]
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
try:
    for l in driver.find_elements_by_xpath('//h2[@class="h2heading truncate"]/a'):
        links1.append(l.get_attribute('href'))
        time.sleep(1)
except NoSuchElementException:
        links1.append("-")
        time.sleep(1)
for page in range(0,10):
        nxt_button=driver.find_elements_by_xpath('//div[@class="pagination"]/ul/li[@class="next"]/a')#scraping the list of buttons from the page
        time.sleep(2)
        try:
            driver.get(nxt_button[1].get_attribute('href'))#getting the link from the list for next page
            time.sleep(2)
        except:
            driver.get(nxt_button[0].get_attribute('href'))
            time.sleep(2)
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        time.sleep(2)
        try:
            for l in driver.find_elements_by_xpath('//h2[@class="h2heading truncate"]/a'):
                links1.append(l.get_attribute('href'))
                time.sleep(1)
        except NoSuchElementException:
                links1.append("-")
                time.sleep(1)

# %%
len(links1)
# Out:
# 269

# %%
# Opening the homepage of cartrade

url = "https://www.cartrade.com/"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="ucity"]').click()
driver.find_element_by_xpath('//*[@id="ucity"]/optgroup[1]/option[5]').click()
driver.find_element_by_xpath('//*[@id="rvwtop"]/div/div[1]/div[2]/div[2]/input').click()
time.sleep(2)
bodytype = driver.find_element_by_xpath('//*[@id="selectlistarrow6"]')
Hatchback = driver.find_element_by_xpath('//*[@id="body_Hatchback"]')
Sedan = driver.find_element_by_xpath('//*[@id="body_Sedan"]')
SUV = driver.find_element_by_xpath('//*[@id="body_SUV"]')
Van_Minivan = driver.find_element_by_xpath('//*[@id="body_Van_Minivan"]')
action= ActionChains(driver)
action.move_to_element(bodytype).move_to_element(Hatchback).click().move_to_element(Sedan).click().move_to_element(SUV).click().move_to_element(Van_Minivan).click().perform()

# %%
links2=[]
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
try:
    for l in driver.find_elements_by_xpath('//h2[@class="h2heading truncate"]/a'):
        links2.append(l.get_attribute('href'))
        time.sleep(1)
except NoSuchElementException:
        links2.append("-")
        time.sleep(1)
        
for page in range(0,10):
        nxt_button=driver.find_elements_by_xpath('//div[@class="pagination"]/ul/li[@class="next"]/a')#scraping the list of buttons from the page
        time.sleep(2)
        try:
            driver.get(nxt_button[1].get_attribute('href'))#getting the link from the list for next page
            time.sleep(2)
        except:
            driver.get(nxt_button[0].get_attribute('href'))
            time.sleep(2)
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        time.sleep(2)
        try:
            for l in driver.find_elements_by_xpath('//h2[@class="h2heading truncate"]/a'):
                links2.append(l.get_attribute('href'))
                time.sleep(1)
        except NoSuchElementException:
                links2.append("-")
                time.sleep(1)

# %%
len(links2)
# Out:
# 272

# %%
# Opening the homepage of cartrade

url = "https://www.cartrade.com/"
driver.get(url)

time.sleep(2)
driver.find_element_by_xpath('//*[@id="ucity"]').click()
driver.find_element_by_xpath('//*[@id="ucity"]/optgroup[1]/option[6]').click()
driver.find_element_by_xpath('//*[@id="rvwtop"]/div/div[1]/div[2]/div[2]/input').click()
time.sleep(2)
bodytype = driver.find_element_by_xpath('//*[@id="selectlistarrow6"]')
Hatchback = driver.find_element_by_xpath('//*[@id="body_Hatchback"]')
Sedan = driver.find_element_by_xpath('//*[@id="body_Sedan"]')
SUV = driver.find_element_by_xpath('//*[@id="body_SUV"]')
Van_Minivan = driver.find_element_by_xpath('//*[@id="body_Van_Minivan"]')
action= ActionChains(driver)
action.move_to_element(bodytype).move_to_element(Hatchback).click().move_to_element(Sedan).click().move_to_element(SUV).click().move_to_element(Van_Minivan).click().perform()

# %%
links3=[]
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(2)
try:
    for l in driver.find_elements_by_xpath('//h2[@class="h2heading truncate"]/a'):
        links3.append(l.get_attribute('href'))
        time.sleep(1)
except NoSuchElementException:
        links3.append("-")
        time.sleep(1)
        
for page in range(0,3):
        nxt_button=driver.find_elements_by_xpath('//div[@class="pagination"]/ul/li[@class="next"]/a')#scraping the list of buttons from the page
        time.sleep(2)
        try:
            driver.get(nxt_button[1].get_attribute('href'))#getting the link from the list for next page
            time.sleep(2)
        except:
            driver.get(nxt_button[0].get_attribute('href'))
            time.sleep(2)
        driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
        time.sleep(2)
        try:
            for l in driver.find_elements_by_xpath('//h2[@class="h2heading truncate"]/a'):
                links3.append(l.get_attribute('href'))
                time.sleep(1)
        except NoSuchElementException:
                links3.append("-")
                time.sleep(1)

# %%
len(links3)
# Out:
# 99

# %%
links=links1+links2+links3
len(links)
# Out:
# 640

# %%
Brand=[]
Model=[]
Variant=[]
Man_year=[]
Driven_km=[]
Fuel=[]
Num_of_owners=[]
Location=[]
Price=[]

# %%
for url in links:
    driver.get(url)
    time.sleep(2)
    
    try:
        # Extracting Brand
        try:
            b = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[1]/div/ul/li[4]/a/span')  
            Brand.append(b.text)
        except NoSuchElementException:
            Brand.append('-')

        time.sleep(1)
        # Extracting Model
        try:
            m = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[1]/div/ul/li[5]/a/span')   
            Model.append(m.text)
        except NoSuchElementException:
            Model.append('-')

        time.sleep(1)
        # Extracting Variant
        try:
            v = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[1]/div/ul/li[6]/span')  
            Variant.append(v.text)
        except NoSuchElementException:
            Variant.append('-')
        # Extracting Man_year    
        try:
            my = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[8]/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[8]/td[2]')  
            Man_year.append(my.text)
        except NoSuchElementException:
            Man_year.append('-')
        # Extracting Driven_km
        try:
            dk = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[8]/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[3]/td[2]')  
            Driven_km.append(dk.text)
        except NoSuchElementException:
            Driven_km.append('-')
        # Extracting Fuel    
        try:
            f = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[8]/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[2]')  
            Fuel.append(f.text)
        except NoSuchElementException:
            Fuel.append('-')
        # Extracting Num_of_owners    
        try:
            no = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[8]/div[1]/div[2]/div[1]/div[4]/table/tbody/tr[5]/td[2]')  
            Num_of_owners.append(no.text)
        except NoSuchElementException:
            Num_of_owners.append('-')
        # Extracting Location     
        try:
            l = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[8]/div[1]/div[2]/div/div[4]/table/tbody/tr[1]/td[2]')  
            Location.append(l.text)
        except NoSuchElementException:
            Location.append('-')
        # Extracting Price
        try:
            p = driver.find_element_by_xpath('//*[@id="idbybody"]/div[2]/div[8]/div[1]/div[2]/div/div[1]/div[1]/span[2]')  
            Price.append(p.text)
        except NoSuchElementException:
            Price.append('-')
    except TimeoutException:
        pass        
    except NoSuchElementException:
        pass

# %%
# dictionary of lists 
dict4 = {'Brand': Brand, 'Model': Model, 'Variant': Variant,'Man_year':Man_year,'Driven_km':Driven_km,'Fuel':Fuel,
         'Num_of_owners':Num_of_owners,'Location':Location,'Price':Price} 
     
df4 = pd.DataFrame(dict4)
  
# saving the dataframe
df4.to_csv('cartrade01.csv')

# %%
filename=['cartrade.csv', 'Olx.csv','carwale.csv','cartrade01.csv']

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in filename])

# %%
combined_csv.to_excel( "Car_Price.xlsx", index=False, encoding='utf-8')

# %%
combined_csv.to_csv( "CarPrice.csv", index=False, encoding='utf-8')

# %%
#end

# %% [markdown]
# ![](https://i.pinimg.com/originals/75/3a/32/753a326847fa99d65d506324c5d95363.gif)
